# %% [markdown]
# # Страховка автомобиля

# %% [markdown]
# * ID : ID водителя
# * AGE : Возраст водителя
# * GENDER : Пол водителя
# * RACE : Раса клиента
# * DRIVING_EXPERIENCE : Стаж вождения
# * EDUCATION : Уровень образования.
# * INCOME : Уровень дохода
# * CREDIT_SCORE : Кредитный рейтинг
# * VEHICLE_OWNERSHIP : Владение (физическое) транспортным средством
# * VEHICLE_YEAR : Год выпуска транспортного средства
# * MARRIED : Нахождение в браке
# * CHILDREN : Наличие детей
# * POSTAL_CODE : Почтовый индекс
# * ANNUAL_MILEAGE : Годовой пробег
# * VEHICLE_TYPE : Тип транспортного средства
# * SPEEDING_VIOLATIONS : Количество превышений скорости
# * DUIS : Количество нарушений, связанных с вождением в нетрезвом виде
# * PAST_ACCIDENTS : Количество предыдущих инцидентов
# * OUTCOME : исход (0 - не требуется страховая выплата, 1 - требуется)
#
# Требуется предсказать **потребуется ли страховая выплата**.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
path = "Car_Insurance_Claim.csv"
data = pd.read_csv(path)

# %%
data.head()
# Out:
#        ID    AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION  \
# 0  569520    65+  female  majority               0-9y  high school
# 1  750365  16-25    male  majority               0-9y         none
# 2  199901  16-25  female  majority               0-9y  high school
# 3  478866  16-25    male  majority               0-9y   university
# 4  731664  26-39    male  majority             10-19y         none
#
#           INCOME  CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  \
# 0    upper class      0.629027                1.0   after 2015      0.0
# 1        poverty      0.357757                0.0  before 2015      0.0
# 2  working class      0.493146                1.0  before 2015      0.0
# 3  working class      0.206013                1.0  before 2015      0.0
# 4  working class      0.388366                1.0  before 2015      0.0
#
#    CHILDREN  POSTAL_CODE  ANNUAL_MILEAGE VEHICLE_TYPE  SPEEDING_VIOLATIONS  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10000 non-null  int64
#  1   AGE                  10000 non-null  object
#  2   GENDER               10000 non-null  object
#  3   RACE                 10000 non-null  object
#  4   DRIVING_EXPERIENCE   10000 non-null  object
#  5   EDUCATION            10000 non-null  object
#  6   INCOME               10000 non-null  object
#  7   CREDIT_SCORE         9018 non-null   float64
#  8   VEHICLE_OWNERSHIP    10000 non-null  float64
#  9   VEHICLE_YEAR         10000 non-null  object
#  10  MARRIED              10000 non-null  float64
#  11  CHILDREN             10000 non-null  float64
#  12  POSTAL_CODE          10000 non-null  int64
#  13  ANNUAL_MILEAGE       9043 non-null   float64
#  14  VEHICLE_TYPE         10000 non-null  object
# ...

# %% [markdown]
# Приведём Object к категориальным типам

# %%
data['AGE'] = data['AGE'].astype('category')
data['GENDER'] = data['GENDER'].astype('category')
data['RACE'] = data['RACE'].astype('category')
data['DRIVING_EXPERIENCE'] = data['DRIVING_EXPERIENCE'].astype('category')
data['EDUCATION'] = pd.Categorical(data['EDUCATION'])
data['INCOME'] = data['INCOME'].astype('category')
data['VEHICLE_YEAR'] = data['VEHICLE_YEAR'].astype('category')
data['VEHICLE_TYPE'] = data['VEHICLE_TYPE'].astype('category')
data['OUTCOME'] = data['OUTCOME'].astype('bool')

del data['ID']
del data['POSTAL_CODE']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   AGE                  10000 non-null  category
#  1   GENDER               10000 non-null  category
#  2   RACE                 10000 non-null  category
#  3   DRIVING_EXPERIENCE   10000 non-null  category
#  4   EDUCATION            10000 non-null  category
#  5   INCOME               10000 non-null  category
#  6   CREDIT_SCORE         9018 non-null   float64
#  7   VEHICLE_OWNERSHIP    10000 non-null  float64
#  8   VEHICLE_YEAR         10000 non-null  category
#  9   MARRIED              10000 non-null  float64
#  10  CHILDREN             10000 non-null  float64
#  11  ANNUAL_MILEAGE       9043 non-null   float64
#  12  VEHICLE_TYPE         10000 non-null  category
#  13  SPEEDING_VIOLATIONS  10000 non-null  int64
#  14  DUIS                 10000 non-null  int64
# ...

# %% [markdown]
# Посмотрим на какие категории они разбились.

# %%
(data['AGE'].dtype,
data['GENDER'].dtype,
data['RACE'].dtype,
data['DRIVING_EXPERIENCE'].dtype,
data['EDUCATION'].dtype,
data['INCOME'].dtype,
data['VEHICLE_YEAR'].dtype,
data['VEHICLE_TYPE'].dtype,
data['OUTCOME'].dtype
)
# Out:
# (CategoricalDtype(categories=['16-25', '26-39', '40-64', '65+'], ordered=False),
#  CategoricalDtype(categories=['female', 'male'], ordered=False),
#  CategoricalDtype(categories=['majority', 'minority'], ordered=False),
#  CategoricalDtype(categories=['0-9y', '10-19y', '20-29y', '30y+'], ordered=False),
#  CategoricalDtype(categories=['high school', 'none', 'university'], ordered=False),
#  CategoricalDtype(categories=['middle class', 'poverty', 'upper class', 'working class'], ordered=False),
#  CategoricalDtype(categories=['after 2015', 'before 2015'], ordered=False),
#  CategoricalDtype(categories=['sedan', 'sports car'], ordered=False),
#  dtype('bool'))

# %% [markdown]
# ## Визуализация и анализ данных

# %%
data.describe()
# Out:
#        CREDIT_SCORE  VEHICLE_OWNERSHIP       MARRIED      CHILDREN  \
# count   9018.000000       10000.000000  10000.000000  10000.000000
# mean       0.515813           0.697000      0.498200      0.688800
# std        0.137688           0.459578      0.500022      0.463008
# min        0.053358           0.000000      0.000000      0.000000
# 25%        0.417191           0.000000      0.000000      0.000000
# 50%        0.525033           1.000000      0.000000      1.000000
# 75%        0.618312           1.000000      1.000000      1.000000
# max        0.960819           1.000000      1.000000      1.000000
#
#        ANNUAL_MILEAGE  SPEEDING_VIOLATIONS         DUIS  PAST_ACCIDENTS
# count     9043.000000         10000.000000  10000.00000    10000.000000
# mean     11697.003207             1.482900      0.23920        1.056300
# std       2818.434528             2.241966      0.55499        1.652454
# min       2000.000000             0.000000      0.00000        0.000000
# ...

# %% [markdown]
# Большая половины водителей не попадали в аварии, не превышали скорость и не были замечены в вождении в нетрезвом виде. Наибольшее число превышений скорости = 22, вождений в нетрезвом виде = 6, инциндентов = 15. Так же большая часть владеет автомобилем, а не берет его в аренду.

# %%
data.describe(include=['category'])
# Out:
#           AGE  GENDER      RACE DRIVING_EXPERIENCE    EDUCATION       INCOME  \
# count   10000   10000     10000              10000        10000        10000
# unique      4       2         2                  4            3            4
# top     26-39  female  majority               0-9y  high school  upper class
# freq     3063    5010      9012               3530         4157         4336
#
#        VEHICLE_YEAR VEHICLE_TYPE
# count         10000        10000
# unique            2            2
# top     before 2015        sedan
# freq           6967         9523

# %% [markdown]
# Основную массу составляют люди с возрастом в диапозоне 26-39 лет, с водительским стажем до 9 лет, с высоким достатком, но закончивших только старшую школу. Большая часть автомобилей является седанами до 2015 года.

# %% [markdown]
# Построим диаграммы рассеивания

# %%
sns.pairplot(data, hue='OUTCOME')
plt.legend()
pass
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Не видно очевидной корреляции между параметрами. Построим таблицу корреляции

# %%
data.corr()
# Out:
# C:\Users\MADZEROPIE\AppData\Local\Temp\ipykernel_9840\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                      CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# CREDIT_SCORE             1.000000           0.312037  0.281238  0.220658
# VEHICLE_OWNERSHIP        0.312037           1.000000  0.175626  0.125990
# MARRIED                  0.281238           0.175626  1.000000  0.287009
# CHILDREN                 0.220658           0.125990  0.287009  1.000000
# ANNUAL_MILEAGE          -0.174453          -0.097433 -0.462193 -0.447655
# SPEEDING_VIOLATIONS      0.204542           0.133868  0.218855  0.220415
# DUIS                     0.127366           0.086567  0.120840  0.115354
# PAST_ACCIDENTS           0.180978           0.119521  0.215269  0.206295
# ...

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
ax = sns.heatmap(data.corr(), annot=True)
# Out:
# C:\Users\MADZEROPIE\AppData\Local\Temp\ipykernel_9840\3497971999.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   ax = sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# Здесь можно увидеть достаточно заметную взаимную корреляцию между превышением скорости, вождением в нетрезвом виде и числом аварий. Что довольно логично. В общем корреляция по признакам не превышает 0,5.

# %% [markdown]
# Однако значение пробега заметно кореллирует с тем, есть ли ребенок и женат ли человек. Давайте попробуем выкинуть и посмотрим, будет ли лучше. (Спойлер: НЕТ. Я проверил, для KNN становится лучше, но крайне незначительно и только при определенном числе соседей, в то время как на решающих деревьях ошибка заметно возрастает.)

# %%
# del data['ANNUAL_MILEAGE']

# %% [markdown]
# ## Обработка пропущенных значений
# Просто заполним их медианой и будем надеяться, что всё будет хорошо.

# %%
data.fillna(data.median(axis = 0), axis=0 , inplace=True)
data.isna().sum()
# Out:
# C:\Users\MADZEROPIE\AppData\Local\Temp\ipykernel_9840\3744457309.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.fillna(data.median(axis = 0), axis=0 , inplace=True)
# AGE                    0
# GENDER                 0
# RACE                   0
# DRIVING_EXPERIENCE     0
# EDUCATION              0
# INCOME                 0
# CREDIT_SCORE           0
# VEHICLE_OWNERSHIP      0
# VEHICLE_YEAR           0
# MARRIED                0
# CHILDREN               0
# ANNUAL_MILEAGE         0
# VEHICLE_TYPE           0
# SPEEDING_VIOLATIONS    0
# DUIS                   0
# PAST_ACCIDENTS         0
# OUTCOME                0
# dtype: int64

# %% [markdown]
# ## Обработка категориальных признаков
# Закодируем категориальные признаки числовыми.

# %%
cat_cols = ['AGE','GENDER','RACE','DRIVING_EXPERIENCE','EDUCATION','INCOME','VEHICLE_YEAR','VEHICLE_TYPE']
# based on https://stackoverflow.com/a/52306709/12383832
data_fin = data
for col in cat_cols:
    data_fin = pd.concat([data_fin,pd.get_dummies(data_fin[col],prefix=col)],axis=1).drop([col],axis=1)

data_fin
# Out:
#       CREDIT_SCORE  VEHICLE_OWNERSHIP  MARRIED  CHILDREN  ANNUAL_MILEAGE  \
# 0         0.629027                1.0      0.0       1.0         12000.0
# 1         0.357757                0.0      0.0       0.0         16000.0
# 2         0.493146                1.0      0.0       0.0         11000.0
# 3         0.206013                1.0      0.0       1.0         11000.0
# 4         0.388366                1.0      0.0       0.0         12000.0
# ...            ...                ...      ...       ...             ...
# 9995      0.582787                1.0      0.0       0.0         16000.0
# 9996      0.522231                1.0      0.0       1.0         12000.0
# 9997      0.470940                1.0      0.0       1.0         14000.0
# 9998      0.364185                0.0      0.0       1.0         13000.0
# 9999      0.435225                1.0      1.0       1.0         13000.0
#
#       SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  OUTCOME  AGE_16-25  ...  \
# ...

# %% [markdown]
# ## Разбиение выборки

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.25, random_state = 451)
for train_index, test_index in split.split(data_fin, data_fin['OUTCOME']):
    strat_train_set = data_fin.loc[train_index]
    strat_test_set = data_fin.loc[test_index]

# %%
x_train = strat_train_set.drop('OUTCOME', axis = 1)
y_train = strat_train_set['OUTCOME'].copy()

x_test = strat_test_set.drop('OUTCOME', axis = 1)
y_test = strat_test_set['OUTCOME'].copy()

# %% [markdown]
# ## Нормализация признаков

# %%
from sklearn.preprocessing import MinMaxScaler

x_train = MinMaxScaler().fit_transform(x_train)
x_test = MinMaxScaler().fit_transform(x_test)

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=10)

# %%
print("Train: ", 1-knn.score(x_train, y_train))
print("Test: ", 1-knn.score(x_test, y_test))
# Out:
# Train:  0.14946666666666664
# Test:  0.19199999999999995

# %%
from sklearn.metrics import confusion_matrix

y_test_predict = knn.predict(x_test)
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1540  177]
#  [ 303  480]]

# %% [markdown]
# Попробуем с другим числом соседей

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
print("Train: ", 1-knn.score(x_train, y_train))
print("Test: ", 1-knn.score(x_test, y_test))
# Out:
# Train:  0.1353333333333333
# Test:  0.19520000000000004

# %%
from sklearn.metrics import confusion_matrix

y_test_predict = knn.predict(x_test)
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1503  214]
#  [ 274  509]]

# %% [markdown]
# При меньшем числе соседей ошибка не уменьшилась.
# Однако она всё равно была бы немного выше, если бы мы выкинули пробег
# Основная ошибка false negative.

# %% [markdown]
# ### Подбор числа соседей (почему бы и нет)

# %%
def foo(neighbors, x_train, y_train, x_test, y_test):
    knn = KNeighborsClassifier(n_neighbors = neighbors)
    knn.fit(x_train, y_train)
    y_train_pred = knn.predict(x_train)
    y_test_pred = knn.predict(x_test)
    train_err = np.mean(y_train != y_train_pred)
    test_err = np.mean(y_test != y_test_pred)
    return train_err, test_err

# %%
from joblib import Parallel, delayed
neighbors_arr = np.array([i for i in range(2,103,4)])

results = Parallel(n_jobs=-1)(delayed(foo)(neighbors, x_train, y_train, x_test, y_test) for neighbors in neighbors_arr)
train_err = list(map(lambda a: a[0], results))
test_err = list(map(lambda a: a[1], results))

# %%
plt.plot(neighbors_arr, train_err, 'r-o', label = 'train')
plt.plot(neighbors_arr, test_err, 'b-o', label = 'test')
plt.title('Error vs. neighbors number')
plt.xlabel('neighbors')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.11533333333333333 0.1832

# %%
neighbors_opt = neighbors_arr[test_err == min_test_err]
print(neighbors_opt)
# Out:
# [54]

# %% [markdown]
# ## Random forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 250)
rf.fit(x_train, y_train)

err_train = np.mean(y_train != rf.predict(x_train))
err_test  = np.mean(y_test  != rf.predict(x_test))

print(err_train, err_test)

y_test_predict = rf.predict(x_test)
print(confusion_matrix(y_test, y_test_predict))
# Out:
# 0.0005333333333333334 0.1832
# [[1526  191]
#  [ 267  516]]

# %% [markdown]
# Ни увеличение, ни уменьшение количества деревьев не приводят к заметному уменьшению ошибки на тестовой выборке...

# %% [markdown]
# ## Выводы

# %% [markdown]
# Из-за того, что наступление страховых случаев сильно зависит от случайности, невозможно точно предсказать произойдет он или нет. Возможно не хвататает каких-то других признаков.

# %% [markdown]
# # Нейронная сеть

# %% [markdown]
# ## 1 Скрытый слой

# %%
from sklearn.neural_network import MLPClassifier

mlp_model = MLPClassifier(hidden_layer_sizes = (50,),
                          solver = 'lbfgs',
                          activation = 'logistic',
                          max_iter=2000,
                          random_state = 451,
                          verbose=1,
                          tol=1e-3)

# %%
mlp_model.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(50,), max_iter=2000,
#               random_state=451, solver='lbfgs', tol=0.001, verbose=1)

# %% [markdown]
# ### Ошибка на обучающей выборке

# %%
y_train_predict = mlp_model.predict(x_train)
err_train  = np.mean(y_train  != y_train_predict)
err_train
# Out:
# 0.1556

# %% [markdown]
# ### Ошибка на тестовой выборке

# %%
y_test_predict = mlp_model.predict(x_test)
err_test  = np.mean(y_test  != y_test_predict)
err_test
# Out:
# 0.1696

# %%
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1522  195]
#  [ 229  554]]

# %% [markdown]
# ## 2 Скрытых слоя

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (50,20),
                          solver = 'lbfgs', 
                          activation = 'logistic',
                          max_iter=2000,
                          random_state = 42,
                          verbose=1,
                          tol=1e-3)

# %%
mlp_model.fit(x_train, y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(50, 20), max_iter=2000,
#               random_state=42, solver='lbfgs', tol=0.001, verbose=1)

# %%
y_train_pred = mlp_model.predict(x_train)
y_test_pred = mlp_model.predict(x_test)
np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred)
# Out:
# (0.15826666666666667, 0.1708)

# %%
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1522  195]
#  [ 229  554]]

# %% [markdown]
# ## Подбор гиперпараметров

# %%
alpha_arr = np.logspace(-4, 5, 10)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(hidden_layer_sizes = (30,), activation = 'logistic',
                           random_state = 42, alpha = alpha, max_iter=2000 )
    mlp_model.fit(x_train, y_train)

    y_train_pred = mlp_model.predict(x_train)
    y_test_pred = mlp_model.predict(x_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'r-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'b-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.1552 0.16

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [0.01]

# %%
alpha_opt = alpha_opt[0]

# %% [markdown]
# ### При оптимальном alpha

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (30,), random_state = 42, alpha = alpha_opt, activation = 'logistic', max_iter=2000)
mlp_model.fit(x_train, y_train)

y_train_pred = mlp_model.predict(x_train)
y_test_pred = mlp_model.predict(x_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.15546666666666667
# 0.16

# %%
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1507  210]
#  [ 206  577]]

# %% [markdown]
# ## Подбор числа нейронов при опт. alpha

# %%
def foo(neuron, x_train, y_train, x_test, y_test):
    mlp_model = MLPClassifier(hidden_layer_sizes = (neuron,), activation = 'logistic',
                           random_state = 42, alpha = alpha_opt, max_iter=2000 )
    mlp_model.fit(x_train, y_train)

    y_train_pred = mlp_model.predict(x_train)
    y_test_pred = mlp_model.predict(x_test)
    train_err = np.mean(y_train != y_train_pred)
    test_err = np.mean(y_test != y_test_pred)
    return train_err, test_err

# %%
from joblib import Parallel, delayed
neurons_arr = np.array([i for i in range(2,102)])

results = Parallel(n_jobs=-1)(delayed(foo)(neuron, x_train, y_train, x_test, y_test) for neuron in neurons_arr)
train_err = list(map(lambda a: a[0], results))
test_err = list(map(lambda a: a[1], results))

# %%
plt.semilogx(neurons_arr, train_err, 'r-o', label = 'train')
plt.semilogx(neurons_arr, test_err, 'b-o', label = 'test')
plt.xlim([np.max(neurons_arr), np.min(neurons_arr)])
plt.title('Error vs. neurons number')
plt.xlabel('neurons')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.15426666666666666 0.1588

# %%
neurons_arr = np.array([i for i in range(2,102)])
neurons_opt = neurons_arr[test_err == min_test_err]
print(neurons_opt)
# Out:
# [89]

# %%
neurons_opt = neurons_opt[0]

# %% [markdown]
# ### При оптимальных параметрах

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (neurons_opt,), 
                          random_state = 42, alpha = alpha_opt,
                          activation = 'logistic', max_iter=2000)
mlp_model.fit(x_train, y_train)

y_train_pred = mlp_model.predict(x_train)
y_test_pred = mlp_model.predict(x_test)
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.15546666666666667
# 0.1588

# %%
print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[1507  210]
#  [ 206  577]]

# %% [markdown]
# # Финальные выводы

# %% [markdown]
# Все методы показали схожие результаты с небольшим преимуществом у нейросети после подбора параметров, что говорит о том, что действительно тяжело предсказать произойдёт ли страховой случай.
